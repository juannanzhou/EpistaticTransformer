# %%
## Standard libraries
import os
import numpy as np
import math
import json
from functools import partial

import random as rd

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import GPUtil
import torch
import torch.nn as nn
import sys
sys.path.append('../model')
from utils import amino_acid_to_number, tokenize

device = "cuda:0"

# %%
def sgpu():
    GPUtil.showUtilization()

sgpu()
# Out:
# | ID | GPU  | MEM |
# -------------------
# |  0 |   0% |  3% |
# |  1 |   0% |  0% |
# |  2 |  99% | 33% |
# |  3 |   0% |  0% |
# |  4 | 100% | 36% |
# |  5 |  20% |  1% |
# |  6 |   0% |  0% |
# |  7 | 100% | 36% |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import GPUtil
import torch

# %%
def tokenize(seq):
    numeric_sequence = [amino_acid_to_number[aa] for aa in seq]
    return numeric_sequence

# tokenization function

def get_tokenizer(seqs):
    letters = []
    for seq in seqs:
        letters.extend(list(seq))
    letters = list(set(letters))
    rule = dict(zip(letters, range(len(letters))))
    return rule

# %%
in_path = "../Data/Data_prepared/"
file_name = "Starita2013.csv"

# %%
datafile = pd.read_csv(in_path + file_name, index_col=None)

# %%
datafile = datafile.iloc[:-1]

# %%
# # save a small binary dataset

# muts = list(datafile.mutated_sequence)

# muts = list([list(mut) for mut in muts])

# muts = pd.DataFrame(muts)

# bi_alphabet = [list(muts.iloc[:, i].value_counts()[:2].keys()) for i in range(muts.shape[1])]

# seq = datafile.mutated_sequence.iloc[0]

# def keep(seq):
#     in_alphabet = [seq[i] in bi_alphabet[i] for i in range(len(bi_alphabet))]
#     in_alphabet = np.array(in_alphabet)
#     return np.prod(in_alphabet)

# keeps = np.array([keep(seq) for seq in datafile.mutated_sequence])
# print(keeps.sum())

# datafile = datafile[keeps==1]

# %%
# site specific tokenization

def get_A2N_list(seqs):
    seqs_ = list([list(seq) for seq in seqs])

    seqs_ = list([list(seq) for seq in seqs])

    seqs__ = pd.DataFrame(seqs_)

    alphabet_by_site = [list(seqs__.iloc[:, i].unique()) for i in range(seqs__.shape[1])]

    A2N_list = [dict(zip(alphabet, range(len(alphabet)))) for alphabet in alphabet_by_site]    
    
    return A2N_list

def tokenize(seq):
    numeric_sequence = [A2N_list[i][seq[i]] for i in range(len(A2N_list))]
    return numeric_sequence

seqs = datafile.mutated_sequence
A2N_list = get_A2N_list(seqs)

# %%
# seqs = datafile.mutated_sequence
# amino_acid_to_number = get_tokenizer(seqs)

# %%
plt.hist(datafile['hd'], bins=20)
plt.show()

plt.scatter(datafile['hd'], datafile['DMS_score'])
plt.show()

plt.hist(datafile.DMS_score, bins=20)
plt.show()

# %%
seqs_tokenized = [tokenize(seq) for seq in datafile.mutated_sequence]
seqs = torch.tensor(seqs_tokenized)
seqs_df = pd.DataFrame(seqs.cpu().numpy())
L = len(seqs[0])

# Find variable sites

counts = {i: seqs_df[i].value_counts() for i in range(seqs_df.shape[1])}

n_aas = [len(counts[i]) for i in range(len(counts))]
sites_var = np.where(np.array(n_aas) != 1)

# %%
seqs = seqs.cpu()
seqs = seqs[:, sites_var].squeeze(1)
L = seqs.shape[1]

# %%
from torch.nn.functional import one_hot
seqs1h = one_hot(seqs)
print(seqs1h.shape)
# Out:
# torch.Size([98297, 102, 19])

# %%
seqs_tokenized = [tokenize(seq) for seq in datafile.mutated_sequence]
seqs = torch.tensor(seqs_tokenized)
seqs_df = pd.DataFrame(seqs.cpu().numpy())
L = len(seqs[0])

# Find variable sites

counts = {i: seqs_df[i].value_counts() for i in range(seqs_df.shape[1])}

n_aas = [len(counts[i]) for i in range(len(counts))]
sites_var = np.where(np.array(n_aas) != 1)

plt.plot(n_aas)
plt.show()

seqs = seqs.cpu()
seqs = seqs[:, sites_var].squeeze(1)
L = seqs.shape[1]

from torch.nn.functional import one_hot
seqs1h = one_hot(seqs)
print(seqs1h.shape)

seqs1hf = seqs1h.view(-1, L*seqs1h.shape[-1])
print(seqs1hf.shape)
# Out:
# torch.Size([98297, 102, 19])
# torch.Size([98297, 1938])

# %%
phenotypes = torch.tensor(list(datafile.DMS_score)).float()
phenotypes = phenotypes.unsqueeze(1)

# %%
# phenotypes = torch.log(phenotypes)

# %%
import torch
import torch.utils.data as data

class ProtDataset(data.Dataset):
    def __init__(self, feats, labels, train=True):    
        self.train = train
        self.feats = feats
        self.labels = labels
    
    def __len__(self):
        return len(self.feats)
    
    def __getitem__(self, idx):
        
        X = self.feats[idx]
        y = self.labels[idx]

        return X, y

# %%
# min_d = 20
# sub_list = list(np.where(datafile['hd'] < min_d)[0])
# comp_list = list(np.where(datafile['hd'] >= min_d)[0])

# num_train = 50000
# num_test = 1000

# train_list = np.random.choice(sub_list, num_train)
# test_list = np.random.choice(comp_list, num_test)

# %%
len(datafile)
# Out:
# 98297

# %%
num_train = 20000
num_test = 1000

sub_list = np.random.choice(range(len(datafile)), num_train)
comp_list = list(set(range(len(datafile))).difference(sub_list))

train_list = np.random.choice(sub_list, num_train)
test_list = np.random.choice(comp_list, num_test)

# %%
plt.hist(phenotypes[train_list].flatten().numpy(), density=True, alpha=.5)
plt.hist(phenotypes[test_list].flatten().numpy(), density=True, alpha=.5)
plt.show()

# %% [markdown]
# ### Fit Linear model

# %%
X = seqs1hf.float().to(device)
y = phenotypes.to(device)

X_train, y_train = X[train_list], y[train_list]
X_test, y_test = X[test_list], y[test_list]

train_dataset = ProtDataset(X_train, y_train)
train_loader = data.DataLoader(train_dataset,
                               batch_size=1000,
                               shuffle=True,
                               drop_last=False)

X_train.shape
# Out:
# torch.Size([20000, 1938])

# %%
mlp_width = X_train.shape[-1]

# %%
# # Define the linear regression model as provided
# class LinearRegressionModel(nn.Module):
#     @nn.compact
#     def __call__(self, x, train:bool):
#         batch_size = x.shape[0]        
#         x = x.reshape(batch_size, -1)
#         weights = self.param('weights', lambda key, shape: jax.random.normal(key, shape=shape), (L*AA_size,))
#         bias = self.param('bias', lambda key, shape: jax.random.normal(key, shape=shape), ())
#         scale = self.param('scale', lambda key, shape: jax.random.normal(key, shape=shape), ())
#         x = jnp.dot(x, weights)
#         x = x.reshape(-1, 1)
#         x = nn.BatchNorm(use_running_average=not train)(x)
#         x = x.reshape(-1)        

#         # return linear_output
#         return scale*nn.sigmoid(x) + bias

# # Define a custom loss function (mean squared error)
# def mse_loss(params, x, y):
#     predictions, _ = model.apply(params, x, train=True, mutable=['batch_stats'])
#     loss = jnp.mean((predictions - y) ** 2)
#     return loss

# # Create an instance of the model
# model = LinearRegressionModel()

# %%
class LinearModel(nn.Module):
    def __init__(self):
        super(LinearModel, self).__init__()
        self.fc = nn.Linear(mlp_width, 1)
        self.sigmoid_norm = nn.BatchNorm1d(1, affine=False)                
        self.sigmoid = nn.Sigmoid()
        self.sigmoid_scale = nn.Linear(1, 1)        
        
    def forward(self, x):
        x = self.fc(x)
        # x = self.sigmoid_norm(x)
        x = self.sigmoid(x)
        x = self.sigmoid_scale(x)        
            
        return x

# %%
x, y = next(iter(train_loader))
model = LinearModel().cuda()
output = model(x)

plt.hist(output.detach().cpu().numpy())
plt.show()

# %%
import torch.optim as optim
import torch
import torch.nn as nn


from scipy.stats import pearsonr
learning_rate = 0.01
epochs = 100

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(epochs):
    total_loss = 0
    for batch_inputs, batch_targets in train_loader:
        model.train()
        optimizer.zero_grad()
        outputs = model(batch_inputs)
        loss = criterion(outputs, batch_targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_loader)}")
        model.eval()
        pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
        print(pearsonr(pred, true)[0]**2)
# Out:
# Epoch 1/100, Loss: 2.2216139256954195
# 0.3851505678744051
# Epoch 11/100, Loss: 2.0065371334552764
# 0.38848730011848887
# Epoch 21/100, Loss: 2.0081591248512267
# 0.3929451317078518
# Epoch 31/100, Loss: 2.000747764110565
# 0.39164000733321175
# Epoch 41/100, Loss: 2.0026923179626466
# 0.39171702308079775
# Epoch 51/100, Loss: 2.0013250529766085
# 0.3917763964548216
# Epoch 61/100, Loss: 2.008975440263748
# 0.39363676069197867
# Epoch 71/100, Loss: 2.0043140828609465
# 0.3925635569228262
# Epoch 81/100, Loss: 1.9927899241447449
# 0.39396995061397233
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 15
#      13 for epoch in range(epochs):
#      14     total_loss = 0
# ---> 15     for batch_inputs, batch_targets in train_loader:
#      16         model.train()
#      17         optimizer.zero_grad()
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# KeyboardInterrupt:

# %%
pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
plt.scatter(pred, true)

# %% [markdown]
# ### Fit transformer

# %%
AA_size = int(mlp_width/L)

# %%
seqs = seqs + AA_size*torch.tensor(range(L))

# %%
X = seqs.to(device)
y = phenotypes.to(device)

X_train, y_train = X[train_list], y[train_list]
X_test, y_test = X[test_list], y[test_list]

train_dataset = ProtDataset(X_train, y_train)
train_loader = data.DataLoader(train_dataset,
                               batch_size=1000,
                               shuffle=True,
                               drop_last=False)

# %%
embedding = nn.Embedding(input_dim, hidden_dim).to(device)

# %%
# This works!!
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np


import torch
import torch.nn as nn

class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hidden_dim, num_heads, dropout):
        super(MultiHeadAttentionLayer, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(hidden_dim, num_heads, dropout)
        # self.multihead_attn = MultiheadAttention(hidden_dim, hidden_dim, num_heads)        
        self.layer_norm = nn.LayerNorm(hidden_dim)
        
    def forward(self, x):
        attn_output, _ = self.multihead_attn(x, x, x)
        x = x + attn_output
        # x = self.layer_norm(x + attn_output)
        return x

class CustomTransformer(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_heads, dropout):
        super(CustomTransformer, self).__init__()

        self.embedding = nn.Embedding(input_dim, hidden_dim)
        
        self.transformer_layers = nn.ModuleList([
            MultiHeadAttentionLayer(hidden_dim, num_heads, dropout) for _ in range(num_layers)
        ])
        # self.fc = nn.Linear(hidden_dim, 1)
        self.fc = nn.Linear(hidden_dim, 1)
        self.sigmoid_norm = nn.BatchNorm1d(1, affine=False)        
        self.sigmoid = nn.Sigmoid()
        self.phi_scaling = nn.Linear(1, 1)
        self.sigmoid_scaling = nn.Linear(1, 1)

    def forward(self, x):

        x = self.embedding(x)
        x = x.permute(1, 0, 2)  # seq_len x batch x hidden_dim
        
        for layer in self.transformer_layers:
            x = layer(x)
            
        x = x.permute(1, 0, 2)
        x = torch.mean(x, dim=1)  # batch x hidden_dim
        # x = x.flatten(1)
        # print(x.shape)
        x = self.fc(x)  # batch x 1 (scalar)
        # x = self.sigmoid_norm(x)
        mean = torch.mean(x)
        std = torch.std(x)
        x = (x - mean) / std
        
        x = self.phi_scaling(x)
        x = self.sigmoid(x)
        x = self.sigmoid_scaling(x)

        return x

# %%
# This works!!
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np


import torch
import torch.nn as nn

class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hidden_dim, num_heads, dropout):
        super(MultiHeadAttentionLayer, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(hidden_dim, num_heads, dropout)
        # self.multihead_attn = MultiheadAttention(hidden_dim, hidden_dim, num_heads)        
        self.layer_norm = nn.LayerNorm(hidden_dim)
        
    def forward(self, x):
        attn_output, _ = self.multihead_attn(x, x, x)
        x = x + attn_output
        # x = self.layer_norm(x + attn_output)
        return x

class CustomTransformer(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_heads, dropout):
        super(CustomTransformer, self).__init__()

        self.embedding = nn.Embedding(input_dim, hidden_dim)
        
        self.transformer_layers = nn.ModuleList([
            MultiHeadAttentionLayer(hidden_dim, num_heads, dropout) for _ in range(num_layers)
        ])
        # self.fc = nn.Linear(hidden_dim, 1)
        self.fc = nn.Linear(L, 1)
        self.sigmoid_norm = nn.BatchNorm1d(1, affine=False)        
        self.sigmoid = nn.Sigmoid()
        self.phi_scaling = nn.Linear(1, 1)
        self.sigmoid_scaling = nn.Linear(1, 1)
        

    def forward(self, x):

        x = self.embedding(x)
        x = x.permute(1, 0, 2)  # seq_len x batch x hidden_dim
        
        for layer in self.transformer_layers:
            x = layer(x)
            
        x = x.permute(1, 0, 2)
        x = x.mean(-1)  # batch x hidden_dim
        # x = x.flatten(1)
        # print(x.shape)
        x = self.fc(x)  # batch x 1 (scalar)
        # x = self.sigmoid_norm(x)
        mean = torch.mean(x)
        std = torch.std(x)
        x = (x - mean) / std
        
        x = self.phi_scaling(x)
        x = self.sigmoid(x)
        x = self.sigmoid_scaling(x)

        return x

# %%
sequence_length = L
input_dim = 19*L
output_dim = 1
hidden_dim = 4
num_layers = 1
num_heads = 2
dropout = 0.1

model = CustomTransformer(input_dim, hidden_dim, num_layers, num_heads, dropout).to(device)

# %%
x, y = next(iter(train_loader))
output = model(x)

# %%
from scipy.stats import pearsonr
learning_rate = 0.01
epochs = 1000

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch_inputs, batch_targets in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_inputs)
        loss = criterion(outputs, batch_targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_loader)}")
        model.eval()
        pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
        print(pearsonr(pred, true)[0]**2)
# Out:
# Epoch 1/1000, Loss: 3.6509196877479555
# 0.1209865331760687
# Epoch 11/1000, Loss: 2.352297329902649
# 0.2999595553981265
# Epoch 21/1000, Loss: 2.178297996520996
# 0.3289855256226626
# Epoch 31/1000, Loss: 2.1163953840732574
# 0.3442672511322461
# Epoch 41/1000, Loss: 2.0846020758152006
# 0.3578128666695475
# Epoch 51/1000, Loss: 2.06905220746994
# 0.35849262456867786
# Epoch 61/1000, Loss: 2.0550931692123413
# 0.36431941508689913
# Epoch 71/1000, Loss: 2.0473717868328096
# 0.3674656213735085
# Epoch 81/1000, Loss: 2.034666270017624
# 0.3682146382789571
# Epoch 91/1000, Loss: 2.0231355726718903
# 0.3647159307632905
# Epoch 101/1000, Loss: 2.0247782349586485
# 0.36562353856942215
# Epoch 111/1000, Loss: 2.0128719210624695
# 0.36399788920665466
# Epoch 121/1000, Loss: 2.0092238664627073
# 0.3637601370794175
# Epoch 131/1000, Loss: 2.0061170995235442
# 0.3623895760401448
# Epoch 141/1000, Loss: 2.0048228085041044
# 0.36037423065529567
# Epoch 151/1000, Loss: 1.999016684293747
# 0.35955440136967215
# Epoch 161/1000, Loss: 1.998011964559555
# 0.3612308761558069
# Epoch 171/1000, Loss: 1.9959498047828674
# 0.3588275871802996
# Epoch 181/1000, Loss: 1.9848969280719757
# 0.35919745529774505
# Epoch 191/1000, Loss: 1.9853356182575226
# 0.3578269359185665
# Epoch 201/1000, Loss: 1.9828585088253021
# 0.35749149415423775
# Epoch 211/1000, Loss: 1.9846917390823364
# 0.36050698276483967
# Epoch 221/1000, Loss: 1.9795754671096801
# 0.35927609186626663
# Epoch 231/1000, Loss: 1.9787453651428222
# 0.35893340561580633
# Epoch 241/1000, Loss: 1.9729063510894775
# 0.3599083731941553
# Epoch 251/1000, Loss: 1.9672120928764343
# 0.35668188616691426
# Epoch 261/1000, Loss: 1.9681319892406464
# 0.35591841548510694
# Epoch 271/1000, Loss: 1.9619376718997956
# 0.35574210253135835
# Epoch 281/1000, Loss: 1.968403697013855
# 0.3538735597893745
# Epoch 291/1000, Loss: 1.957797920703888
# 0.35362384565039157
# Epoch 301/1000, Loss: 1.9615041136741638
# 0.35261009417239225
# Epoch 311/1000, Loss: 1.952317041158676
# 0.3506332235406032
# Epoch 321/1000, Loss: 1.9482610106468201
# 0.34986203252685216
# Epoch 331/1000, Loss: 1.9442960560321807
# 0.350572874294301
# Epoch 341/1000, Loss: 1.9364496648311615
# 0.3509851943087419
# Epoch 351/1000, Loss: 1.9325214684009553
# 0.34890623676920923
# Epoch 361/1000, Loss: 1.9305723369121552
# 0.34778318724815344
# Epoch 371/1000, Loss: 1.9289406478404998
# 0.3464739471325868
# Epoch 381/1000, Loss: 1.9288580894470215
# 0.3441224426070145
# Epoch 391/1000, Loss: 1.9176993787288665
# 0.34184228852028614
# Epoch 401/1000, Loss: 1.9174557387828828
# 0.34199578560619376
# Epoch 411/1000, Loss: 1.9121123254299164
# 0.34286005701232686
# Epoch 421/1000, Loss: 1.9092390298843385
# 0.33993278303050495
# Epoch 431/1000, Loss: 1.9045052528381348
# 0.3428310692576513
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[282], line 11
#       9 model.train()
#      10 total_loss = 0
# ---> 11 for batch_inputs, batch_targets in train_loader:
#      12     optimizer.zero_grad()
#      13     outputs = model(batch_inputs)
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /apps/pytorch/2.0.1/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# KeyboardInterrupt:

# %%
np.mean((outputs.flatten().cpu().detach().numpy() -  batch_targets.flatten().cpu().detach().numpy())**2)
# Out:
# 1.9451346

# %%
pearsonr(outputs.flatten().cpu().detach().numpy(), batch_targets.flatten().cpu().detach().numpy())[0]**2
# Out:
# 0.48705115619550676

# %%
plt.scatter(outputs.flatten().cpu().detach().numpy(), batch_targets.flatten().cpu().detach().numpy())

# %%
model.eval()

pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
print(f' Test R2 = {pearsonr(pred, true)[0]**2}')
plt.scatter(pred, true)
plt.show()
# Out:
#  Test R2 = 0.3639507559784717

# %%
# batch_size = 1000
# sequence_length = L
# input_dim = AA_size*L
# output_dim = 1
# hidden_dim = 128 #
# num_layers = 6
# num_heads = 4 #
# dropout = 0.4 #

# model = CustomTransformer(input_dim, hidden_dim, num_layers, num_heads, dropout).to(device)

# %%
# This works!!
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np


import torch
import torch.nn as nn

class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hidden_dim, num_heads, dropout):
        super(MultiHeadAttentionLayer, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(hidden_dim, num_heads, dropout)
        # self.multihead_attn = MultiheadAttention(hidden_dim, hidden_dim, num_heads)        
        self.layer_norm = nn.LayerNorm(hidden_dim)
        
    def forward(self, x):
        attn_output, _ = self.multihead_attn(x, x, x)
        x = x + attn_output
        # x = self.layer_norm(x + attn_output)
        return x

class CustomTransformer(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_heads, dropout):
        super(CustomTransformer, self).__init__()

        self.embedding = nn.Embedding(input_dim, hidden_dim)
        
        self.transformer_layers = nn.ModuleList([
            MultiHeadAttentionLayer(hidden_dim, num_heads, dropout) for _ in range(num_layers)
        ])
        # self.fc = nn.Linear(hidden_dim, 1)
        self.fc = nn.Linear(hidden_dim*L, 1)        
        self.sigmoid_norm = nn.BatchNorm1d(1, affine=False)        
        self.sigmoid = nn.Sigmoid()
        self.phi_scaling = nn.Linear(1, 1)
        self.sigmoid_scaling = nn.Linear(1, 1)

    def forward(self, x):

        x = self.embedding(x)
        x = x.permute(1, 0, 2)  # seq_len x batch x hidden_dim
        
        for layer in self.transformer_layers:
            x = layer(x)
            
        # x = torch.mean(x, dim=0)  # batch x hidden_dim
        x = x.permute(1, 0, 2)
        x = x.flatten(1)
        # print(x.shape)
        x = self.fc(x)  # batch x 1 (scalar)
        # x = self.sigmoid_norm(x)
        mean = torch.mean(x)
        std = torch.std(x)
        x = (x - mean) / std
        
        x = self.phi_scaling(x)
        x = self.sigmoid(x)
        x = self.sigmoid_scaling(x)

        return x

# %%
batch_size = 1000
sequence_length = L
input_dim = AA_size*L
output_dim = 1
hidden_dim = 128
num_layers = 2
num_heads = 4
dropout = 0.3

model = CustomTransformer(input_dim, hidden_dim, num_layers, num_heads, dropout).to(device)

# %%
x, y = next(iter(train_loader))
output = model(x)

# %%
from scipy.stats import pearsonr
learning_rate = 0.001 #
epochs = 200

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch_inputs, batch_targets in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_inputs)
        loss = criterion(outputs, batch_targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    if epoch % 10 == 0:
        print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_loader)}")
        model.eval()
        pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
        print(pearsonr(pred, true)[0]**2)
# Out:
# Epoch 1/200, Loss: 0.26750506460666656
# 0.15994170074132724
# Epoch 11/200, Loss: 0.2687106132507324
# 0.34059073483781643
# Epoch 21/200, Loss: 0.2557465732097626
# 0.47904402803389995
# Epoch 31/200, Loss: 0.2455505132675171
# 0.6129977570963114
# Epoch 41/200, Loss: 0.26046163588762283
# 0.6781137471608665
# Epoch 51/200, Loss: 0.23485494405031204
# 0.6976350004252371
# Epoch 61/200, Loss: 0.23784176260232925
# 0.704518470931086
# Epoch 71/200, Loss: 0.24960602819919586
# 0.7133826358658633
# Epoch 81/200, Loss: 0.23217106610536575
# 0.7036986705582879
# Epoch 91/200, Loss: 0.23729504644870758
# 0.7033133411032515
# Epoch 101/200, Loss: 0.22009660303592682
# 0.7093863688054679
# Epoch 111/200, Loss: 0.23252280801534653
# 0.6948482385330998
# Epoch 121/200, Loss: 0.2256951928138733
# 0.687548940792348
# Epoch 131/200, Loss: 0.2095743864774704
# 0.7047996968495845
# Epoch 141/200, Loss: 0.20424828678369522
# 0.6837028125810185
# Epoch 151/200, Loss: 0.19680020958185196
# 0.6999624008136086
# Epoch 161/200, Loss: 0.1952330395579338
# 0.6929678139272891
# Epoch 171/200, Loss: 0.19193217903375626
# 0.6946545116298246
# Epoch 181/200, Loss: 0.17676296830177307
# 0.6971306690124955
# Epoch 191/200, Loss: 0.18249648809432983
# 0.6846949512501616

# %%
model.eval()

pred, true = model(X_test.flatten(1)).flatten().detach().cpu().numpy(), y_test.flatten().detach().cpu().numpy()
print(f' Test R2 = {pearsonr(pred, true)[0]**2}')
plt.scatter(pred, true)
plt.show()
# Out:
#  Test R2 = 0.5841056057700698
